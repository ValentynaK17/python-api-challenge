# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import holoviews as hv


# Import API key
from api_keys import geoapify_key

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID") 
# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp C  Humidity  \
# City_ID
# 0                  DUDINKA  69.4058   86.1778       -0.21        98
# 1              YELLOWKNIFE  62.4560 -114.3525        7.29        93
# 2                  STANLEY -51.7000  -57.8500        7.16        76
# 3        PORT-AUX-FRANCAIS -49.3500   70.2167        1.62        72
# 4             INVERCARGILL -46.4000  168.3500        9.45        91
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        6.43      RU  1695937428
# 1               100        2.06      CA  1695937428
# 2                26        6.47      FK  1695937429
# 3                28       14.98      TF  1695937429
# 4                97        6.26      NZ  1695937429

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
hv.extension('bokeh')
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 500,
    frame_height = 360,
    size = "Humidity",
    scale = 0.6,
    color="City"
)

# Display the map
map_plot
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df_loc=city_data_df[(city_data_df["Max Temp C"]>20)&(city_data_df["Max Temp C"]<26)&(city_data_df["Wind Speed"]<3)&(city_data_df["Cloudiness"]==0)]

# Drop any rows with null values
city_data_df_loc.dropna(inplace=True)

# Display sample data
city_data_df_loc
# Out:
#                             City      Lat       Lng  Max Temp C  Humidity  \
# City_ID
# 53                         KILIS  36.7161   37.1150       24.13        65
# 54                       TSIOMBE -25.3000   45.4833       22.95        55
# 71                        NEWMAN -23.3667  119.7333       20.83        18
# 254                         OMIS  43.4447   16.6886       20.96        53
# 310      SANTA COLOMA DE FARNERS  41.8667    2.6667       21.95        88
# 331                       TOBRUK  32.0836   23.9764       23.96        77
# 341                       PARKES -33.1333  148.1833       21.31        46
# 349                USHIBUKAMACHI  32.1906  130.0228       23.80        78
# 429                      JACKSON  42.4165 -122.8345       20.51        47
# 493       LA MANGA DEL MAR MENOR  37.6413   -0.7165       22.45        87
# 496                      TOLIARA -23.3500   43.6667       22.49        83
# 557                  ZHAOBAOSHAN  29.9695  121.6875       24.01        88
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 53                0        2.96      TR  1695937448
# 54                0        2.97      MG  1695937449
# 71                0        2.45      AU  1695937456
# 254               0        2.98      HR  1695937522
# 310               0        0.00      ES  1695937551
# 331               0        2.50      LY  1695937559
# 341               0        0.82      AU  1695937563
# 349               0        2.36      JP  1695937566
# 429               0        2.57      US  1695937521
# 493               0        1.54      ES  1695937620
# 496               0        2.43      MG  1695937621
# 557               0        1.36      CN  1695937644

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df=city_data_df_loc[["City","Country","Lat","Lng","Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=""

# Display sample data
hotel_df
# Out:
#                             City Country      Lat       Lng  Humidity  \
# City_ID
# 53                         KILIS      TR  36.7161   37.1150        65
# 54                       TSIOMBE      MG -25.3000   45.4833        55
# 71                        NEWMAN      AU -23.3667  119.7333        18
# 254                         OMIS      HR  43.4447   16.6886        53
# 310      SANTA COLOMA DE FARNERS      ES  41.8667    2.6667        88
# 331                       TOBRUK      LY  32.0836   23.9764        77
# 341                       PARKES      AU -33.1333  148.1833        46
# 349                USHIBUKAMACHI      JP  32.1906  130.0228        78
# 429                      JACKSON      US  42.4165 -122.8345        47
# 493       LA MANGA DEL MAR MENOR      ES  37.6413   -0.7165        87
# 496                      TOLIARA      MG -23.3500   43.6667        83
# 557                  ZHAOBAOSHAN      CN  29.9695  121.6875        88
#
#         Hotel Name
# City_ID
# 53
# 54
# 71
# 254
# 310
# 331
# 341
# 349
# 429
# 493
# 496
# 557

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 #units=meter
params = {
    "categories":"accommodation.hotel",
    
    "limit":1,
    "apiKey":geoapify_key
}


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon=row["Lng"]
    lat=row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# KILIS - nearest hotel: Olea Otel Kilis
# TSIOMBE - nearest hotel: No hotel found
# NEWMAN - nearest hotel: Mia Mia House in the Desert
# OMIS - nearest hotel: Hotel Plaža
# SANTA COLOMA DE FARNERS - nearest hotel: Fonda Joan
# TOBRUK - nearest hotel: فندق زهرة البطنان -طبرق
# PARKES - nearest hotel: Commercial Hotel
# USHIBUKAMACHI - nearest hotel: Hotel Harbor Inn
# JACKSON - nearest hotel: Brookside
# LA MANGA DEL MAR MENOR - nearest hotel: Hotel Entremares
# TOLIARA - nearest hotel: Ambary
# ZHAOBAOSHAN - nearest hotel: 招宝山饭店
#                             City Country      Lat       Lng  Humidity  \
# City_ID
# 53                         KILIS      TR  36.7161   37.1150        65
# 54                       TSIOMBE      MG -25.3000   45.4833        55
# 71                        NEWMAN      AU -23.3667  119.7333        18
# 254                         OMIS      HR  43.4447   16.6886        53
# 310      SANTA COLOMA DE FARNERS      ES  41.8667    2.6667        88
# 331                       TOBRUK      LY  32.0836   23.9764        77
# 341                       PARKES      AU -33.1333  148.1833        46
# 349                USHIBUKAMACHI      JP  32.1906  130.0228        78
# 429                      JACKSON      US  42.4165 -122.8345        47
# 493       LA MANGA DEL MAR MENOR      ES  37.6413   -0.7165        87
# 496                      TOLIARA      MG -23.3500   43.6667        83
# 557                  ZHAOBAOSHAN      CN  29.9695  121.6875        88
#
#                           Hotel Name
# City_ID
# 53                   Olea Otel Kilis
# 54                    No hotel found
# 71       Mia Mia House in the Desert
# 254                      Hotel Plaža
# 310                       Fonda Joan
# 331          فندق زهرة البطنان -طبرق
# 341                 Commercial Hotel
# 349                 Hotel Harbor Inn
# 429                        Brookside
# 493                 Hotel Entremares
# 496                           Ambary
# 557                            招宝山饭店

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hv.extension('bokeh')
map_plot_hotels = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "CartoLight",
    frame_width = 500,
    frame_height = 360,
    size = "Humidity",
    scale = 0.6,
    color="City",
    hover_cols=["Hotel Name","Country"]
)

# Display the map
map_plot_hotels
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
